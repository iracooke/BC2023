# %% [markdown]
# This is a jupyter notebook.
#
# It consists of series of cells that contain either text or computer code. Jupyter notebooks are very useful for doing and learning bioinformatics because they allow documentation (text cells) to be mixed together with code for manipulating data, running programs and creating plots.
#
# This tutorial is
#
# You can click on a cell to select it and make it the active cell.  The active cell will have a thin coloured border and a thicker border on the left.
#
# The cell you are reading is a text cell. Click on it to make it the currently active/selected cell. The active cell will have thin coloured border around it with a thicker border on the left.
#
# The cell immediately below this one is a code cell.
#
# You type commands into code cells and the notebook will interpret these commands just as though you were working at the unix command line.
#
# The notebook will not actually run your code cells until you tell it to.  You can do this by first selecting the cell and then using the menu to select Cell -> Run Cells.
#
# Try running the code cell below. What output does it produce?

# %%
fortune
# Out:
# I will never lie to you.

# %%
?? What output is produced by pwd?

# %% [markdown]
# You can also add new cells using the insert menu. Add a new cell and try experimenting by running the following commands in the cell.
#
# List the contents of the current directory with `ls`
#
# ```bash
# ls
# ```
#
# List contents of the current directory's parent.
#
# ```bash
# ls ../
# ```

# %% [markdown]
# Running cells by clicking the menus is slow and laborious. A much quicker way is to type control - enter.
#
# Try this on the cell below.

# %%
ls -G ../
# Out:
# README.md      bin            notebook_intro setup
# assembly       clboot         raw_data       uploads

# %% [markdown]
# ??? What is the effect of the `-G` option when used with the `ls` command?

# %% [markdown]
# #### Creating Files
#
# Using the `mkdir` command create a directory called "E1".
#
# Enter your command into the blank cell below

# %%
mkdir E1

# %% [markdown]
# What command would you use to check that this worked properly?

# %%
ls -lG
# Out:
# total 8
# drwxr-xr-x  2 icooke  staff    68 26 Mar 14:57 E1
# -rw-r--r--  1 icooke  staff  3879 26 Mar 14:58 jupyter_intro.ipynb

# %%
Change directory into the newly created E1 directory. 

Use the `touch` command to create the following files within this directory

1_H.txt
2_E.txt
3_L.txt
4_L.txt
5_0.txt

# %%
cd E1/; touch 1_H.txt 2_E.txt 3_L.txt 4_L.txt 5_0.txt

# %%
ls -1
# Out:
# 1_H.txt
# 2_E.txt
# 3_L.txt
# 4_L.txt
# 5_0.txt
